# %% [markdown]
# # SMART WATER ANALYTICS - TEAM 4 INTERNS - EXPLORE AI
#
# ##### A PROJECT ON WATER AVAILABILITY MANAGEMENT

# %% [markdown]
# ### Team Members
#
# #### Viwe Mqaqa                             | South Africa | viwe@explore-datascience.net | Supervisor
#
# ##### Oreoluwa Onyekachi Olaiya  | Nigeria | olaiyaoreoluwa3@gmail.com
# ##### Christian Divinefavour           | Nigeria | contact.christiandivinefavour@gmail.com
# ##### Gabriel Asiegbu                      | Nigeria | gwap2@live.com
# ##### Titus Olang'                             | Kenya  | tityewanjohi@gmail.com
# ##### Michael Kanu                          | Nigeria | michaelkanu01@yahoo.com
# ##### Michael Omosebi                    | Nigeria | omosebimichael@live.com

# %% [markdown]
# ## Project Overview
#
# The Acea Group is one of the leading Italian multiutility operators. Listed on the Italian Stock Exchange since 1999, the company manages and develops water and electricity networks and environmental services. Acea is the foremost Italian operator in the water services sector supplying 9 million inhabitants in Lazio, Tuscany, Umbria, Molise, Campania.
#
# This project focuses on the water sector to help Acea Group preserve precious waterbodies. As it is easy to imagine, a water supply company struggles with the need to forecast the water level in a waterbody (water spring, lake, river, or aquifer) to handle daily consumption. During fall and winter waterbodies are refilled, but during spring and summer they start to drain. To help preserve the health of these waterbodies it is important to predict the most efficient water availability, in terms of level and water flow for each day of the year.
#
#
# #### Kaggle Link: https://www.kaggle.com/competitions/acea-water-prediction
# #### GitHub Repo: https://github.com/Christian-Divinefavour/smart-water-analytics-explore_ai_team4

# %% [markdown]
# ## Data Overview

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
aquifers = pd.read_csv('Aquifer_Auser.csv')
rivers = pd.read_csv('River_Arno.csv')
lakes = pd.read_csv('Lake_Bilancino.csv')
spring = pd.read_csv('Water_Spring_Amiata.csv')

desc = pd.read_excel('datasets_description.xlsx')
#desc = desc[((desc.Database == 'Aquifer_Auser') & (desc.Database == 'River_Arno') & (desc.Database == 'Lake_Bilancino') & (desc.Database == 'Water_Spring_Amiata'))]
pd.set_option('display.max_rows', desc.shape[0]+1)
pd.options.display.max_colwidth = 500

desc
# Out:
#                           Database  \
# 0                    Aquifer_Auser
# 1              Water_Spring_Amiata
# 2               Aquifer_Petrignano
# 3                Aquifer_Doganella
# 4                    Aquifer_Luco
# 5                       River_Arno
# 6                  Lake_Bilancino
# 7  Water_Spring_Madonna_di_Canneto
# 8                Water_Spring_Lupa
#
#                                                                                                                                                                                                                                                                                                                               Description  \
# 0  Information about the Auser aquifer. This water body consists of two subsystems, that we call NORH and SOUTH, where the former partly influences the behaviour of the latter.\nThe levels of the NORTH sector are represented by the values of the SAL, PAG, CoS and DIEC wells, while the levels of the SOUTH sector by the LT2 well.
# 1                                             Information about the Amiata aquifer. This aquifer is accessed through the Ermicciolo, Arbure, Bugnano and Galleria Alta springs. \nThe levels and volumes of the four springs are influenced by the parameters: pluviometry, sub-gradation, hydrometry, temperatures and drainage volumes.
# 2                                                                                                                               Information about Petrignano aquifer. \nIt is fed by three underground aquifers separated by low permeability septa; the water table can be considered groundwater and is also fed by the Chiascio river.
# 3                                                                                   Information about Doganella aquifer. The Doganella well field is fed by two underground aquifers: \nthe upper stratum is a water table with a thickness of about 30m while the lower one is a semi-confined artesian aquifer with a thickness of 50m.
# 4                                                                                                                                        Information about Luco aquifer. It is an underground aquifer not fed by rivers or lakes but fed by meteoric infiltration\n and it is accessed through wells called Pozzo_1, Pozzo_3 and Pozzo_4.
# 5                                                                                           Information about Arno river. The Arno is the second largest river in peninsular Italy and the main waterway in Tuscany and it  has a relatively torrential regime, \ndue to the nature of the surrounding soils (marl and impermeable clays)
# 6                                                                                                                                          Information about Bilancino Lake. It is an artificial lake in Mugello, in the province of Florence. \n It has a maximum depth of thirty-one metres and a surface area of 5 square kilometres.
# 7                                                               Information about Madonna di Canneto water spring. The Madonna di Canneto spring is situated at an altitude of 1010m above sea level in the Canneto valley. \nIt does not consist of an aquifer and its source is supplied by the water catchment area of the river Melfa
# 8                                                                                                                                                                                                                                     Information about Lupa water spring. It is located in the Arrone area and is used for drinking use.
#
#                                                                                                                                                                                                                                                                            Output
# 0                                                                                                                                                                                                    Depth_to_Groundwater_SAL, Depth_to_Groundwater_COS, Depth_to_Groundwater_LT2
# 1                                                                                                                                                                                            Flow_Rate_Bugnano, Flow_Rate_Arbure,\n Flow_Rate_Ermicciolo, Flow_Rate_Galleria_Alta
# 2                                                                                                                                                                                                                            Depth_to_Groundwater_P24,\n Depth_to_Groundwater_P25
# 3  Depth_to_Groundwater_Pozzo_1, Depth_to_Groundwater_Pozzo_2, Depth_to_Groundwater_Pozzo_3, Depth_to_Groundwater_Pozzo_4, Depth_to_Groundwater_Pozzo_5, Depth_to_Groundwater_Pozzo_6,\nDepth_to_Groundwater_Pozzo_7, Depth_to_Groundwater_Pozzo_8, Depth_to_Groundwater_Pozzo_9
# 4                                                                                                                                                                                                                                             Depth_to_Groundwater_Podere_Casetta
# 5                                                                                                                                                                                                                                                       Hydrometry_Nave_di_Rosano
# 6                                                                                                                                                                                                                                                         Lake_Level, \nFlow_Rate
# 7                                                                                                                                                                                                                                                                       Flow_Rate
# 8                                                                                                                                                                                                                                                                       Flow_Rate

# %%
pd.set_option('display.max_rows', aquifers.shape[0]+1)
aquifers.T
# Out:
#                                                0           1           2     \
# Date                                     05/03/1998  06/03/1998  07/03/1998
# Rainfall_Gallicano                              NaN         NaN         NaN
# Rainfall_Pontetetto                             NaN         NaN         NaN
# Rainfall_Monte_Serra                            NaN         NaN         NaN
# Rainfall_Orentano                               NaN         NaN         NaN
# Rainfall_Borgo_a_Mozzano                        NaN         NaN         NaN
# Rainfall_Piaggione                              NaN         NaN         NaN
# Rainfall_Calavorno                              NaN         NaN         NaN
# Rainfall_Croce_Arcana                           NaN         NaN         NaN
# Rainfall_Tereglio_Coreglia_Antelminelli         NaN         NaN         NaN
# Rainfall_Fabbriche_di_Vallico                   NaN         NaN         NaN
# Depth_to_Groundwater_LT2                        NaN         NaN         NaN
# Depth_to_Groundwater_SAL                        NaN         NaN         NaN
# Depth_to_Groundwater_PAG                        NaN         NaN         NaN
# Depth_to_Groundwater_CoS                        NaN         NaN         NaN
# Depth_to_Groundwater_DIEC                       NaN         NaN         NaN
# Temperature_Orentano                              0           0           0
# Temperature_Monte_Serra                           0           0         9.2
# Temperature_Ponte_a_Moriano                       0           0           0
# Temperature_Lucca_Orto_Botanico                   0       10.05          10
# Volume_POL                                      NaN         NaN         NaN
# Volume_CC1                                      NaN         NaN         NaN
# Volume_CC2                                      NaN         NaN         NaN
# Volume_CSA                                      NaN         NaN         NaN
# Volume_CSAL                                     NaN         NaN         NaN
# Hydrometry_Monte_S_Quirico                      NaN         NaN         NaN
# Hydrometry_Piaggione                            NaN         NaN         NaN
#
#                                                3           4           5     \
# Date                                     08/03/1998  09/03/1998  10/03/1998
# Rainfall_Gallicano                              NaN         NaN         NaN
# Rainfall_Pontetetto                             NaN         NaN         NaN
# Rainfall_Monte_Serra                            NaN         NaN         NaN
# Rainfall_Orentano                               NaN         NaN         NaN
# Rainfall_Borgo_a_Mozzano                        NaN         NaN         NaN
# Rainfall_Piaggione                              NaN         NaN         NaN
# Rainfall_Calavorno                              NaN         NaN         NaN
# Rainfall_Croce_Arcana                           NaN         NaN         NaN
# Rainfall_Tereglio_Coreglia_Antelminelli         NaN         NaN         NaN
# Rainfall_Fabbriche_di_Vallico                   NaN         NaN         NaN
# Depth_to_Groundwater_LT2                        NaN         NaN         NaN
# Depth_to_Groundwater_SAL                        NaN         NaN         NaN
# Depth_to_Groundwater_PAG                        NaN         NaN         NaN
# Depth_to_Groundwater_CoS                        NaN         NaN         NaN
# Depth_to_Groundwater_DIEC                       NaN         NaN         NaN
# Temperature_Orentano                              0           0           0
# Temperature_Monte_Serra                        11.4        11.4        7.95
# Temperature_Ponte_a_Moriano                       0           0           0
# Temperature_Lucca_Orto_Botanico               13.85       12.85         6.5
# Volume_POL                                      NaN         NaN         NaN
# Volume_CC1                                      NaN         NaN         NaN
# Volume_CC2                                      NaN         NaN         NaN
# Volume_CSA                                      NaN         NaN         NaN
# Volume_CSAL                                     NaN         NaN         NaN
# Hydrometry_Monte_S_Quirico                      NaN         NaN         NaN
# Hydrometry_Piaggione                            NaN         NaN         NaN
#
#                                                6           7           8     \
# Date                                     11/03/1998  12/03/1998  13/03/1998
# Rainfall_Gallicano                              NaN         NaN         NaN
# Rainfall_Pontetetto                             NaN         NaN         NaN
# Rainfall_Monte_Serra                            NaN         NaN         NaN
# Rainfall_Orentano                               NaN         NaN         NaN
# Rainfall_Borgo_a_Mozzano                        NaN         NaN         NaN
# Rainfall_Piaggione                              NaN         NaN         NaN
# Rainfall_Calavorno                              NaN         NaN         NaN
# Rainfall_Croce_Arcana                           NaN         NaN         NaN
# Rainfall_Tereglio_Coreglia_Antelminelli         NaN         NaN         NaN
# Rainfall_Fabbriche_di_Vallico                   NaN         NaN         NaN
# Depth_to_Groundwater_LT2                        NaN         NaN         NaN
# Depth_to_Groundwater_SAL                        NaN         NaN         NaN
# Depth_to_Groundwater_PAG                        NaN         NaN         NaN
# Depth_to_Groundwater_CoS                        NaN         NaN         NaN
# Depth_to_Groundwater_DIEC                       NaN         NaN         NaN
# Temperature_Orentano                              0           0           0
# Temperature_Monte_Serra                        6.15        4.95         5.4
# Temperature_Ponte_a_Moriano                       0           0           0
# Temperature_Lucca_Orto_Botanico                1.85         6.8        9.05
# Volume_POL                                      NaN         NaN         NaN
# Volume_CC1                                      NaN         NaN         NaN
# Volume_CC2                                      NaN         NaN         NaN
# Volume_CSA                                      NaN         NaN         NaN
# Volume_CSAL                                     NaN         NaN         NaN
# Hydrometry_Monte_S_Quirico                      NaN         NaN         NaN
# Hydrometry_Piaggione                            NaN         NaN         NaN
#
#                                                9        ...            8144  \
# Date                                     14/03/1998     ...      21/06/2020
# Rainfall_Gallicano                              NaN     ...               0
# Rainfall_Pontetetto                             NaN     ...             0.4
# Rainfall_Monte_Serra                            NaN     ...               0
# Rainfall_Orentano                               NaN     ...               0
# Rainfall_Borgo_a_Mozzano                        NaN     ...               0
# Rainfall_Piaggione                              NaN     ...               0
# Rainfall_Calavorno                              NaN     ...               0
# Rainfall_Croce_Arcana                           NaN     ...               0
# Rainfall_Tereglio_Coreglia_Antelminelli         NaN     ...               0
# Rainfall_Fabbriche_di_Vallico                   NaN     ...               0
# Depth_to_Groundwater_LT2                        NaN     ...          -12.31
# Depth_to_Groundwater_SAL                        NaN     ...           -5.38
# Depth_to_Groundwater_PAG                        NaN     ...           -1.78
# Depth_to_Groundwater_CoS                        NaN     ...           -5.39
# Depth_to_Groundwater_DIEC                       NaN     ...           -3.78
# Temperature_Orentano                              0     ...           21.35
# Temperature_Monte_Serra                        8.95     ...           18.35
# Temperature_Ponte_a_Moriano                       0     ...               0
# Temperature_Lucca_Orto_Botanico                8.05     ...            22.4
# Volume_POL                                      NaN     ...        -6829.94
# Volume_CC1                                      NaN     ...        -7455.51
# Volume_CC2                                      NaN     ...        -8724.26
# Volume_CSA                                      NaN     ...        -5809.63
# Volume_CSAL                                     NaN     ...         -3000.1
# Hydrometry_Monte_S_Quirico                      NaN     ...            0.32
# Hydrometry_Piaggione                            NaN     ...           -1.01
#
#                                                8145        8146        8147  \
# Date                                     22/06/2020  23/06/2020  24/06/2020
# Rainfall_Gallicano                                0           0           0
# Rainfall_Pontetetto                               0           0           0
# Rainfall_Monte_Serra                              0           0           0
# Rainfall_Orentano                                 0           0           0
# Rainfall_Borgo_a_Mozzano                          0           0           0
# Rainfall_Piaggione                                0           0           0
# Rainfall_Calavorno                                0           0           0
# Rainfall_Croce_Arcana                             0           0           0
# Rainfall_Tereglio_Coreglia_Antelminelli           0           0           0
# Rainfall_Fabbriche_di_Vallico                     0           0           0
# Depth_to_Groundwater_LT2                     -12.33      -12.34      -12.35
# Depth_to_Groundwater_SAL                      -5.43       -5.35       -5.46
# Depth_to_Groundwater_PAG                      -1.85       -1.92       -1.97
# Depth_to_Groundwater_CoS                      -5.39       -5.44       -5.51
# Depth_to_Groundwater_DIEC                     -3.79       -3.81       -3.82
# Temperature_Orentano                          23.15        23.3        24.3
# Temperature_Monte_Serra                       20.75       21.55       21.65
# Temperature_Ponte_a_Moriano                       0           0           0
# Temperature_Lucca_Orto_Botanico               23.05        24.3          25
# Volume_POL                                 -7189.41    -7189.41    -7189.41
# Volume_CC1                                  -7847.9     -7847.9     -7847.9
# Volume_CC2                                 -9183.43    -9183.43    -9183.43
# Volume_CSA                                  -6115.4     -6115.4     -6115.4
# Volume_CSAL                                   -3158       -3158       -3158
# Hydrometry_Monte_S_Quirico                     0.31        0.27        0.25
# Hydrometry_Piaggione                          -1.02       -1.03       -1.04
#
#                                                8148        8149        8150  \
# Date                                     25/06/2020  26/06/2020  27/06/2020
# Rainfall_Gallicano                                0           0           0
# Rainfall_Pontetetto                               0           0           0
# Rainfall_Monte_Serra                              0           0           0
# Rainfall_Orentano                                 0           0           0
# Rainfall_Borgo_a_Mozzano                          0           0           0
# Rainfall_Piaggione                                0           0           0
# Rainfall_Calavorno                                0           0           0
# Rainfall_Croce_Arcana                             0           0           0
# Rainfall_Tereglio_Coreglia_Antelminelli           0           0           0
# Rainfall_Fabbriche_di_Vallico                     0           0           0
# Depth_to_Groundwater_LT2                     -12.35      -12.36      -12.36
# Depth_to_Groundwater_SAL                      -5.57           0        -5.5
# Depth_to_Groundwater_PAG                      -2.03       -2.04        -2.1
# Depth_to_Groundwater_CoS                      -5.59           0       -5.71
# Depth_to_Groundwater_DIEC                     -3.82       -3.83       -3.84
# Temperature_Orentano                          23.05        23.2        23.6
# Temperature_Monte_Serra                       20.25       20.75       21.35
# Temperature_Ponte_a_Moriano                       0           0           0
# Temperature_Lucca_Orto_Botanico                24.2       23.75        24.3
# Volume_POL                                 -7189.41    -7189.41    -7189.41
# Volume_CC1                                  -7847.9     -7847.9     -7847.9
# Volume_CC2                                 -9183.43    -9183.43    -9183.43
# Volume_CSA                                  -6115.4     -6115.4     -6115.4
# Volume_CSAL                                   -3158       -3158       -3158
# Hydrometry_Monte_S_Quirico                     0.21         0.2        0.21
# Hydrometry_Piaggione                          -1.05       -1.03       -1.03
#
#                                                8151        8152        8153
# Date                                     28/06/2020  29/06/2020  30/06/2020
# Rainfall_Gallicano                                0           0           0
# Rainfall_Pontetetto                               0           0           0
# Rainfall_Monte_Serra                              0           0           0
# Rainfall_Orentano                                 0           0           0
# Rainfall_Borgo_a_Mozzano                          0           0           0
# Rainfall_Piaggione                                0           0           0
# Rainfall_Calavorno                                0           0           0
# Rainfall_Croce_Arcana                             0           0           0
# Rainfall_Tereglio_Coreglia_Antelminelli           0           0           0
# Rainfall_Fabbriche_di_Vallico                     0           0           0
# Depth_to_Groundwater_LT2                     -12.37      -12.36      -12.38
# Depth_to_Groundwater_SAL                      -5.49        -5.5       -5.56
# Depth_to_Groundwater_PAG                      -2.14       -2.15       -2.17
# Depth_to_Groundwater_CoS                      -5.73       -5.73       -5.76
# Depth_to_Groundwater_DIEC                     -3.84       -3.84       -3.85
# Temperature_Orentano                             24        22.4       23.95
# Temperature_Monte_Serra                       21.75        18.9        19.9
# Temperature_Ponte_a_Moriano                       0           0           0
# Temperature_Lucca_Orto_Botanico               24.55        23.6       25.05
# Volume_POL                                 -6829.94    -7189.41    -7189.41
# Volume_CC1                                 -7455.51     -7847.9     -7847.9
# Volume_CC2                                 -8724.26    -9183.43    -9183.43
# Volume_CSA                                 -5809.63     -6115.4     -6115.4
# Volume_CSAL                                 -3000.1       -3158       -3158
# Hydrometry_Monte_S_Quirico                     0.23        0.23        0.21
# Hydrometry_Piaggione                          -1.03       -1.02       -1.05
#
# [27 rows x 8154 columns]

# %%
pd.set_option('display.max_rows', rivers.shape[0]+1)
rivers.T
# Out:
#                                  0           1           2           3     \
# Date                       01/01/1998  02/01/1998  03/01/1998  04/01/1998
# Rainfall_Le_Croci                 NaN         NaN         NaN         NaN
# Rainfall_Cavallina                NaN         NaN         NaN         NaN
# Rainfall_S_Agata                  NaN         NaN         NaN         NaN
# Rainfall_Mangona                  NaN         NaN         NaN         NaN
# Rainfall_S_Piero                  NaN         NaN         NaN         NaN
# Rainfall_Vernio                   NaN         NaN         NaN         NaN
# Rainfall_Stia                     NaN         NaN         NaN         NaN
# Rainfall_Consuma                  NaN         NaN         NaN         NaN
# Rainfall_Incisa                   NaN         NaN         NaN         NaN
# Rainfall_Montevarchi              NaN         NaN         NaN         NaN
# Rainfall_S_Savino                 NaN         NaN         NaN         NaN
# Rainfall_Laterina                 NaN         NaN         NaN         NaN
# Rainfall_Bibbiena                 NaN         NaN         NaN         NaN
# Rainfall_Camaldoli                NaN         NaN         NaN         NaN
# Temperature_Firenze               NaN         NaN         NaN         NaN
# Hydrometry_Nave_di_Rosano        1.82        1.94        2.11        1.84
#
#                                  4           5           6           7     \
# Date                       05/01/1998  06/01/1998  07/01/1998  08/01/1998
# Rainfall_Le_Croci                 NaN         NaN         NaN         NaN
# Rainfall_Cavallina                NaN         NaN         NaN         NaN
# Rainfall_S_Agata                  NaN         NaN         NaN         NaN
# Rainfall_Mangona                  NaN         NaN         NaN         NaN
# Rainfall_S_Piero                  NaN         NaN         NaN         NaN
# Rainfall_Vernio                   NaN         NaN         NaN         NaN
# Rainfall_Stia                     NaN         NaN         NaN         NaN
# Rainfall_Consuma                  NaN         NaN         NaN         NaN
# Rainfall_Incisa                   NaN         NaN         NaN         NaN
# Rainfall_Montevarchi              NaN         NaN         NaN         NaN
# Rainfall_S_Savino                 NaN         NaN         NaN         NaN
# Rainfall_Laterina                 NaN         NaN         NaN         NaN
# Rainfall_Bibbiena                 NaN         NaN         NaN         NaN
# Rainfall_Camaldoli                NaN         NaN         NaN         NaN
# Temperature_Firenze               NaN         NaN         NaN         NaN
# Hydrometry_Nave_di_Rosano        1.88        1.79        1.77        1.83
#
#                                  8           9        ...            8207  \
# Date                       09/01/1998  10/01/1998     ...      21/06/2020
# Rainfall_Le_Croci                 NaN         NaN     ...               0
# Rainfall_Cavallina                NaN         NaN     ...               0
# Rainfall_S_Agata                  NaN         NaN     ...               0
# Rainfall_Mangona                  NaN         NaN     ...               0
# Rainfall_S_Piero                  NaN         NaN     ...               0
# Rainfall_Vernio                   NaN         NaN     ...             NaN
# Rainfall_Stia                     NaN         NaN     ...             NaN
# Rainfall_Consuma                  NaN         NaN     ...             NaN
# Rainfall_Incisa                   NaN         NaN     ...             NaN
# Rainfall_Montevarchi              NaN         NaN     ...             NaN
# Rainfall_S_Savino                 NaN         NaN     ...             NaN
# Rainfall_Laterina                 NaN         NaN     ...             NaN
# Rainfall_Bibbiena                 NaN         NaN     ...             NaN
# Rainfall_Camaldoli                NaN         NaN     ...             NaN
# Temperature_Firenze               NaN         NaN     ...             NaN
# Hydrometry_Nave_di_Rosano        1.82        1.63     ...            1.37
#
#                                  8208        8209        8210        8211  \
# Date                       22/06/2020  23/06/2020  24/06/2020  25/06/2020
# Rainfall_Le_Croci                   0           0           0           0
# Rainfall_Cavallina                  0           0           0           0
# Rainfall_S_Agata                    0           0           0           0
# Rainfall_Mangona                    0           0           0           0
# Rainfall_S_Piero                    0           0           0           0
# Rainfall_Vernio                   NaN         NaN         NaN         NaN
# Rainfall_Stia                     NaN         NaN         NaN         NaN
# Rainfall_Consuma                  NaN         NaN         NaN         NaN
# Rainfall_Incisa                   NaN         NaN         NaN         NaN
# Rainfall_Montevarchi              NaN         NaN         NaN         NaN
# Rainfall_S_Savino                 NaN         NaN         NaN         NaN
# Rainfall_Laterina                 NaN         NaN         NaN         NaN
# Rainfall_Bibbiena                 NaN         NaN         NaN         NaN
# Rainfall_Camaldoli                NaN         NaN         NaN         NaN
# Temperature_Firenze               NaN         NaN         NaN         NaN
# Hydrometry_Nave_di_Rosano        1.41        1.38        1.33        1.35
#
#                                  8212        8213        8214        8215  \
# Date                       26/06/2020  27/06/2020  28/06/2020  29/06/2020
# Rainfall_Le_Croci                   0           0           0           0
# Rainfall_Cavallina                  0           0           0           0
# Rainfall_S_Agata                    0           0           0           0
# Rainfall_Mangona                    0           0           0           0
# Rainfall_S_Piero                    0           0           0           0
# Rainfall_Vernio                   NaN         NaN         NaN         NaN
# Rainfall_Stia                     NaN         NaN         NaN         NaN
# Rainfall_Consuma                  NaN         NaN         NaN         NaN
# Rainfall_Incisa                   NaN         NaN         NaN         NaN
# Rainfall_Montevarchi              NaN         NaN         NaN         NaN
# Rainfall_S_Savino                 NaN         NaN         NaN         NaN
# Rainfall_Laterina                 NaN         NaN         NaN         NaN
# Rainfall_Bibbiena                 NaN         NaN         NaN         NaN
# Rainfall_Camaldoli                NaN         NaN         NaN         NaN
# Temperature_Firenze               NaN         NaN         NaN         NaN
# Hydrometry_Nave_di_Rosano        1.34        1.21         1.3        1.19
#
#                                  8216
# Date                       30/06/2020
# Rainfall_Le_Croci                   0
# Rainfall_Cavallina                  0
# Rainfall_S_Agata                    0
# Rainfall_Mangona                    0
# Rainfall_S_Piero                    0
# Rainfall_Vernio                   NaN
# Rainfall_Stia                     NaN
# Rainfall_Consuma                  NaN
# Rainfall_Incisa                   NaN
# Rainfall_Montevarchi              NaN
# Rainfall_S_Savino                 NaN
# Rainfall_Laterina                 NaN
# Rainfall_Bibbiena                 NaN
# Rainfall_Camaldoli                NaN
# Temperature_Firenze               NaN
# Hydrometry_Nave_di_Rosano         1.3
#
# [17 rows x 8217 columns]

# %%
pd.set_option('display.max_rows', lakes.shape[0]+1)
lakes.T
# Out:
#                             0           1           2           3     \
# Date                  03/06/2002  04/06/2002  05/06/2002  06/06/2002
# Rainfall_S_Piero             NaN         NaN         NaN         NaN
# Rainfall_Mangona             NaN         NaN         NaN         NaN
# Rainfall_S_Agata             NaN         NaN         NaN         NaN
# Rainfall_Cavallina           NaN         NaN         NaN         NaN
# Rainfall_Le_Croci            NaN         NaN         NaN         NaN
# Temperature_Le_Croci         NaN         NaN         NaN         NaN
# Lake_Level                249.43      249.43      249.43      249.43
# Flow_Rate                   0.31        0.31        0.31        0.31
#
#                             4           5           6           7     \
# Date                  07/06/2002  08/06/2002  09/06/2002  10/06/2002
# Rainfall_S_Piero             NaN         NaN         NaN         NaN
# Rainfall_Mangona             NaN         NaN         NaN         NaN
# Rainfall_S_Agata             NaN         NaN         NaN         NaN
# Rainfall_Cavallina           NaN         NaN         NaN         NaN
# Rainfall_Le_Croci            NaN         NaN         NaN         NaN
# Temperature_Le_Croci         NaN         NaN         NaN         NaN
# Lake_Level                249.44      249.56      249.57      249.58
# Flow_Rate                   0.31        0.38        0.38        0.48
#
#                             8           9        ...            6593  \
# Date                  11/06/2002  12/06/2002     ...      21/06/2020
# Rainfall_S_Piero             NaN         NaN     ...               0
# Rainfall_Mangona             NaN         NaN     ...               0
# Rainfall_S_Agata             NaN         NaN     ...               0
# Rainfall_Cavallina           NaN         NaN     ...               0
# Rainfall_Le_Croci            NaN         NaN     ...               0
# Temperature_Le_Croci         NaN         NaN     ...           21.95
# Lake_Level                249.57      249.57     ...          250.88
# Flow_Rate                   0.48        0.48     ...             0.6
#
#                             6594        6595        6596        6597  \
# Date                  22/06/2020  23/06/2020  24/06/2020  25/06/2020
# Rainfall_S_Piero               0           0           0           0
# Rainfall_Mangona               0           0           0           0
# Rainfall_S_Agata               0           0           0           0
# Rainfall_Cavallina             0           0           0           0
# Rainfall_Le_Croci              0           0           0           0
# Temperature_Le_Croci       23.05        22.5       22.15       22.35
# Lake_Level                250.86      250.86      250.86      250.87
# Flow_Rate                    0.6         0.6         0.6         0.6
#
#                             6598        6599        6600        6601  \
# Date                  26/06/2020  27/06/2020  28/06/2020  29/06/2020
# Rainfall_S_Piero               0           0           0           0
# Rainfall_Mangona               0           0           0           0
# Rainfall_S_Agata               0           0           0           0
# Rainfall_Cavallina             0           0           0           0
# Rainfall_Le_Croci              0           0           0           0
# Temperature_Le_Croci        22.5        23.4        21.5        23.2
# Lake_Level                250.85      250.84      250.83      250.82
# Flow_Rate                    0.6         0.6         0.6         0.6
#
#                             6602
# Date                  30/06/2020
# Rainfall_S_Piero               0
# Rainfall_Mangona               0
# Rainfall_S_Agata               0
# Rainfall_Cavallina             0
# Rainfall_Le_Croci              0
# Temperature_Le_Croci       22.75
# Lake_Level                 250.8
# Flow_Rate                    0.6
#
# [9 rows x 6603 columns]

# %%
pd.set_option('display.max_rows', spring.shape[0]+1)
spring.T
# Out:
#                                              0           1           2     \
# Date                                   01/01/2000  02/01/2000  03/01/2000
# Rainfall_Castel_del_Piano                     NaN         NaN         NaN
# Rainfall_Abbadia_S_Salvatore                  NaN         NaN         NaN
# Rainfall_S_Fiora                              NaN         NaN         NaN
# Rainfall_Laghetto_Verde                       NaN         NaN         NaN
# Rainfall_Vetta_Amiata                         NaN         NaN         NaN
# Depth_to_Groundwater_S_Fiora_8                NaN         NaN         NaN
# Depth_to_Groundwater_S_Fiora_11bis            NaN         NaN         NaN
# Depth_to_Groundwater_David_Lazzaretti         NaN         NaN         NaN
# Temperature_Abbadia_S_Salvatore               NaN         NaN         NaN
# Temperature_S_Fiora                         -0.15        1.55         2.7
# Temperature_Laghetto_Verde                    NaN         NaN         NaN
# Flow_Rate_Bugnano                             NaN         NaN         NaN
# Flow_Rate_Arbure                              NaN         NaN         NaN
# Flow_Rate_Ermicciolo                          NaN         NaN         NaN
# Flow_Rate_Galleria_Alta                       NaN         NaN         NaN
#
#                                              3           4           5     \
# Date                                   04/01/2000  05/01/2000  06/01/2000
# Rainfall_Castel_del_Piano                     NaN         NaN         NaN
# Rainfall_Abbadia_S_Salvatore                  NaN         NaN         NaN
# Rainfall_S_Fiora                              NaN         NaN         NaN
# Rainfall_Laghetto_Verde                       NaN         NaN         NaN
# Rainfall_Vetta_Amiata                         NaN         NaN         NaN
# Depth_to_Groundwater_S_Fiora_8                NaN         NaN         NaN
# Depth_to_Groundwater_S_Fiora_11bis            NaN         NaN         NaN
# Depth_to_Groundwater_David_Lazzaretti         NaN         NaN         NaN
# Temperature_Abbadia_S_Salvatore               NaN         NaN         NaN
# Temperature_S_Fiora                             4         4.6         4.3
# Temperature_Laghetto_Verde                    NaN         NaN         NaN
# Flow_Rate_Bugnano                             NaN         NaN         NaN
# Flow_Rate_Arbure                              NaN         NaN         NaN
# Flow_Rate_Ermicciolo                          NaN         NaN         NaN
# Flow_Rate_Galleria_Alta                       NaN         NaN         NaN
#
#                                              6           7           8     \
# Date                                   07/01/2000  08/01/2000  09/01/2000
# Rainfall_Castel_del_Piano                     NaN         NaN         NaN
# Rainfall_Abbadia_S_Salvatore                  NaN         NaN         NaN
# Rainfall_S_Fiora                              NaN         NaN         NaN
# Rainfall_Laghetto_Verde                       NaN         NaN         NaN
# Rainfall_Vetta_Amiata                         NaN         NaN         NaN
# Depth_to_Groundwater_S_Fiora_8                NaN         NaN         NaN
# Depth_to_Groundwater_S_Fiora_11bis            NaN         NaN         NaN
# Depth_to_Groundwater_David_Lazzaretti         NaN         NaN         NaN
# Temperature_Abbadia_S_Salvatore               NaN         NaN         NaN
# Temperature_S_Fiora                          3.85         4.3        5.15
# Temperature_Laghetto_Verde                    NaN         NaN         NaN
# Flow_Rate_Bugnano                             NaN         NaN         NaN
# Flow_Rate_Arbure                              NaN         NaN         NaN
# Flow_Rate_Ermicciolo                          NaN         NaN         NaN
# Flow_Rate_Galleria_Alta                       NaN         NaN         NaN
#
#                                              9        ...            7477  \
# Date                                   10/01/2000     ...      21/06/2020
# Rainfall_Castel_del_Piano                     NaN     ...               0
# Rainfall_Abbadia_S_Salvatore                  NaN     ...               0
# Rainfall_S_Fiora                              NaN     ...               0
# Rainfall_Laghetto_Verde                       NaN     ...               0
# Rainfall_Vetta_Amiata                         NaN     ...               0
# Depth_to_Groundwater_S_Fiora_8                NaN     ...          -38.39
# Depth_to_Groundwater_S_Fiora_11bis            NaN     ...           -51.9
# Depth_to_Groundwater_David_Lazzaretti         NaN     ...             NaN
# Temperature_Abbadia_S_Salvatore               NaN     ...           18.35
# Temperature_S_Fiora                          4.45     ...           17.35
# Temperature_Laghetto_Verde                    NaN     ...           16.55
# Flow_Rate_Bugnano                             NaN     ...       -0.341945
# Flow_Rate_Arbure                              NaN     ...        -2.77899
# Flow_Rate_Ermicciolo                          NaN     ...        -5.46878
# Flow_Rate_Galleria_Alta                       NaN     ...        -20.2909
#
#                                              7478        7479        7480  \
# Date                                   22/06/2020  23/06/2020  24/06/2020
# Rainfall_Castel_del_Piano                     0.2           0           0
# Rainfall_Abbadia_S_Salvatore                  6.4           0           0
# Rainfall_S_Fiora                              3.2           0           0
# Rainfall_Laghetto_Verde                         5           0           0
# Rainfall_Vetta_Amiata                           0           0           0
# Depth_to_Groundwater_S_Fiora_8             -38.39      -38.39      -38.39
# Depth_to_Groundwater_S_Fiora_11bis          -51.9       -51.9       -51.9
# Depth_to_Groundwater_David_Lazzaretti         NaN         NaN         NaN
# Temperature_Abbadia_S_Salvatore              19.7        20.3       21.15
# Temperature_S_Fiora                          18.5       19.45       19.25
# Temperature_Laghetto_Verde                   18.7        19.2        19.3
# Flow_Rate_Bugnano                       -0.359942   -0.359942   -0.359942
# Flow_Rate_Arbure                         -2.92525    -2.92525    -2.92525
# Flow_Rate_Ermicciolo                     -5.75661    -5.75661    -5.75661
# Flow_Rate_Galleria_Alta                  -21.3589    -21.3589    -21.3589
#
#                                              7481        7482        7483  \
# Date                                   25/06/2020  26/06/2020  27/06/2020
# Rainfall_Castel_del_Piano                       0           0           0
# Rainfall_Abbadia_S_Salvatore                    0           0           0
# Rainfall_S_Fiora                                0           0           0
# Rainfall_Laghetto_Verde                         0           0           0
# Rainfall_Vetta_Amiata                           0           0           0
# Depth_to_Groundwater_S_Fiora_8             -38.38      -38.38      -38.38
# Depth_to_Groundwater_S_Fiora_11bis          -51.9      -51.89      -51.89
# Depth_to_Groundwater_David_Lazzaretti     -303.27     -303.27     -303.27
# Temperature_Abbadia_S_Salvatore             21.45        20.7        20.5
# Temperature_S_Fiora                          18.2        18.3       17.95
# Temperature_Laghetto_Verde                   19.8        19.2       18.85
# Flow_Rate_Bugnano                       -0.359942   -0.359942   -0.359942
# Flow_Rate_Arbure                         -2.92525    -2.92525    -2.92525
# Flow_Rate_Ermicciolo                     -5.75661    -5.75661    -5.75661
# Flow_Rate_Galleria_Alta                  -21.3589    -21.3589    -21.3589
#
#                                              7484        7485        7486
# Date                                   28/06/2020  29/06/2020  30/06/2020
# Rainfall_Castel_del_Piano                       0           0           0
# Rainfall_Abbadia_S_Salvatore                    0           0           0
# Rainfall_S_Fiora                                0           0           0
# Rainfall_Laghetto_Verde                         0           0           0
# Rainfall_Vetta_Amiata                           0           0           0
# Depth_to_Groundwater_S_Fiora_8             -38.38      -38.37      -38.37
# Depth_to_Groundwater_S_Fiora_11bis         -51.89      -51.89      -51.89
# Depth_to_Groundwater_David_Lazzaretti     -303.27     -303.28     -303.27
# Temperature_Abbadia_S_Salvatore              22.1       22.45          22
# Temperature_S_Fiora                          19.9       20.15       20.35
# Temperature_Laghetto_Verde                  20.45        20.2        21.1
# Flow_Rate_Bugnano                       -0.341945   -0.359942   -0.359942
# Flow_Rate_Arbure                         -2.77899    -2.92525    -2.92525
# Flow_Rate_Ermicciolo                     -5.46878    -5.75661    -5.75661
# Flow_Rate_Galleria_Alta                  -20.2909    -21.3589    -21.3589
#
# [16 rows x 7487 columns]

# %% [markdown]
# #### Aquifers

# %%
aquifers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8154 entries, 0 to 8153
# Data columns (total 27 columns):
# Date                                       8154 non-null object
# Rainfall_Gallicano                         5295 non-null float64
# Rainfall_Pontetetto                        5295 non-null float64
# Rainfall_Monte_Serra                       5289 non-null float64
# Rainfall_Orentano                          5295 non-null float64
# Rainfall_Borgo_a_Mozzano                   5295 non-null float64
# Rainfall_Piaggione                         4930 non-null float64
# Rainfall_Calavorno                         5295 non-null float64
# Rainfall_Croce_Arcana                      5295 non-null float64
# Rainfall_Tereglio_Coreglia_Antelminelli    5295 non-null float64
# Rainfall_Fabbriche_di_Vallico              5295 non-null float64
# Depth_to_Groundwater_LT2                   4802 non-null float64
# Depth_to_Groundwater_SAL                   4545 non-null float64
# Depth_to_Groundwater_PAG                   3807 non-null float64
# Depth_to_Groundwater_CoS                   4315 non-null float64
# Depth_to_Groundwater_DIEC                  3270 non-null float64
# Temperature_Orentano                       8154 non-null float64
# Temperature_Monte_Serra                    8154 non-null float64
# Temperature_Ponte_a_Moriano                8154 non-null float64
# Temperature_Lucca_Orto_Botanico            8154 non-null float64
# Volume_POL                                 5660 non-null float64
# Volume_CC1                                 5660 non-null float64
# Volume_CC2                                 5660 non-null float64
# Volume_CSA                                 5660 non-null float64
# Volume_CSAL                                5660 non-null float64
# Hydrometry_Monte_S_Quirico                 7241 non-null float64
# Hydrometry_Piaggione                       6119 non-null float64
# dtypes: float64(26), object(1)
# memory usage: 1.7+ MB
